# %% [markdown]
# # NAME : Rutuja Mali

# %% [markdown]
# ## Data science and Business Analytics Intern At CODERS READY

# %% [markdown]
# ###  Batch: DS22

# %% [markdown]
# # Exploratory Data Analysis On Global Terrorism

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### 1) We Explored the Global Terrorism Dataset . This data is downloaded from internate and try to explored data set by using python tools.

# %% [markdown]
# #### 2) The Aim of these analysis is that we need to find out the hot zone of terrorism attack and what all are the security issues and inside. we need to try by the exploratory data analysis.

# %% [markdown]
# First we import the libraries pandas,numpy,matplotlib,scipy and plotly.
#
# we define the path of the object.
#
# there are two part of the these task
#
# 1) Explore the data set
#
# 2) Explore the best graphical representation

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as gp
import seaborn as sns
import scipy as sp

# %% [markdown]
# ●          we need to import the global dataset.
#
#
#
#
# here,I have import the plotly library. The plotly is a Free and open source of graphing library for python.it is an interactive ,open source plotting library. It is base on pandas.

# %%
# import the csv.file
#build up the pandas dataframe
#visualize the dataset
data = pd.read_csv("C://Users//Rutuja Mali//Downloads//globalterrorism.csv" , encoding ='ISO-8859-1')
# Out:
# C:\Users\Rutuja Mali\AppData\Local\Temp\ipykernel_17572\1030578556.py:4: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("C://Users//Rutuja Mali//Downloads//globalterrorism.csv" , encoding ='ISO-8859-1')

# %%
data
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
data.head()    ## It represent the 1 st five row of the particular data.
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
pd.set_option("display.max_columns" ,None)
data.info()       ##The information contains the number of columns, column labels, column data types, memory usage, range index,
                   #and the number of cells in each column (non-null values).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
data.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
data['caualities'] = data['nkill']+ data['nwound']
data.shape
# Out:
# (181691, 136)

# %%
print("country with highest Terrorist Attacks:",data['country_txt'].value_counts().index[0])
print("Maximum people killed in an attack:", data['nkill'].max())
print("Year with the most attack:" , data['iyear'].value_counts().idxmax())
print("Year with the least attack:" , data['iyear'].value_counts().idxmin())
print("Most attack Types:" , data["attacktype1_txt"].value_counts().idxmax())
print("Most Active Group:" , data ['gname'].value_counts().index[1])
# Out:
# country with highest Terrorist Attacks: Iraq
# Maximum people killed in an attack: 1570.0
# Year with the most attack: 2014
# Year with the least attack: 1971
# Most attack Types: Bombing/Explosion
# Most Active Group: Taliban

# %%
#Rename the columns
data.rename(columns={'iyear': 'Year', 'imonth': 'Month', 'iday': 'Day', 'country_txt': 'Country' ,'provstate': 'State', 'region_txt':'Region' , 'attacktype1_txt': 'Attacktype','targtype1': 'Target','nkill': 'Killed','nwound': 'Wounded','summary':'Summary','gname':'Group','targtype1_txt': 'Target_type','weaptype1_txt': 'Weapon_type','motive': 'Motive'},inplace=True)
data['Casualities'] = data.Killed + data.Wounded

# %%
#filtering out the important dataset those are using further processing
data = data[['Year','Month','Day','Country','State','Region','city' ,'latitude','longitude','Attacktype','Killed','Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive','Casualities']]

# %%
data.head()
# Out:
#    Year  Month  Day             Country    State                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      Attacktype  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
# ...

# %%
data.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# State             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# Attacktype          0
# Killed          10313
# Wounded         16311
# Target              0
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# Casualities     16874
# dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
plt.subplots(figsize=(15,6))
year_cas = data.groupby('Year').Casualities.sum().to_frame().reset_index()
year_cas.columns = ['Year','Casualities']
sns.barplot(x = year_cas.Year,y = year_cas.Casualities,palette = 'RdYlGn_r', edgecolor= sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number of Casualities Each Year')
plt.show()

# %% [markdown]
# ##### In these graph we can understand the number of casualities increasing and decreasing by year. but particular in the year2015 it has been highest number od casualities.

# %%
plt.subplots(figsize=(15,6))
country_attacks = data.Country.value_counts()[:15].reset_index()
country_attacks.columns = ['Country','Total Attacks']
sns.barplot(x = country_attacks.Country,y = country_attacks['Total Attacks'],palette = 'OrRd_r', edgecolor= sns.color_palette('dark',10))
plt.xticks(rotation=30)
plt.title('Number of Total Attack in Each Year')
plt.show()

# %% [markdown]
# ###### These graph is depend on number of total attack in each country where IRAQ has been highest number of terrorist attack for a by pakistan , afghanistan and india.

# %%
pd.crosstab(data.Year,data.Region).plot(kind='area',figsize=(15,6))
plt.title('Terrorist Activities by Region in each Year')
plt.ylabel('Number of Attacks')
plt.show()

# %% [markdown]
# ##### In these graph we can see the terrorist activities by each region . so here Australasia and oceania in 2010it has been in the highest number of terrorist attack.

# %%
plt.figure(figsize = (13,7))
sns.countplot(data['Attacktype'],order = data['Attacktype'].value_counts().index,palette= sns.color_palette("flare"))
plt.xlabel('Weapons used')
plt.ylabel('Resulting Death Count')
plt.title('Forms of attack')
plt.xticks(rotation=90 )
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ###### Bombing Explosion has the most common type of terroriest attack .

# %%
plt.subplots(figsize=(15,6))
sns.barplot(data['Country'].value_counts()[:15].index,data['Country'].value_counts()[:15].values,palette='mako')
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### Top countries affected in global terrorist attack are Iraq has face to highest number of terrorist attackfor the pakistan ,afghanistan.

# %%
plt.subplots(figsize=(10,6))
count_cas = data.groupby('Country').Casualities.sum().to_frame().reset_index().sort_values('Casualities', ascending= False)[:15]
sns.barplot(x=count_cas.Country,y = count_cas.Casualities,palette='OrRd_r',edgecolor=sns.color_palette('dark',15))
plt.xticks(rotation= 45)
plt.title('Number of Total Casualities in Each Country')
plt.show()

# %%
region_attacks = data.Region.value_counts().to_frame().reset_index()
region_attacks.columns=['Region','Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=region_attacks.Region,y= region_attacks['Total Attacks'],palette='OrRd_r',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number Of Total Attack in Each Region')
plt.show()

# %% [markdown]
# #####  here middle east and the north africa has the highest number of attack by region and then south asia and next south america .

# %%
from wordcloud import WordCloud

# %%
attack_type = data.Attacktype.value_counts().to_frame().reset_index()
attack_type.columns=['Attack Type','Total Attacks']
plt.subplots(figsize=(15,6))
sns.barplot(x=attack_type['Attack Type'],y=attack_type['Total Attacks'],palette='viridis',edgecolor=sns.color_palette('dark',10))
plt.xticks(rotation=90)
plt.title('Number of Total Attacks Type ')
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
print('wordCloud is Install and Imported')
# Out:
# wordCloud is Install and Imported

# %%
file = open("C://Users//Rutuja Mali//Downloads//globalterrorism.csv").read()

# %%
stopwords = set(STOPWORDS)

# %%
wordcloud= WordCloud(background_color='White',width=512,height=384,stopwords=stopwords)

# %%
wordcloud.generate(file)

# %%
cities= data.Target.dropna(False)
wordcloud.generate(file)
fig = plt.figure(figsize=(20,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Popular Target',fontdict={'family':'serif','color':'black','weight':'bold','size':26})
plt.show()
# Out:
# C:\Users\Rutuja Mali\AppData\Local\Temp\ipykernel_24884\2836449374.py:1: FutureWarning: In a future version of pandas all arguments of Series.dropna will be keyword-only.
#   cities= data.Target.dropna(False)

# %%
group_attacks = data.Grokup.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns =['Treeorist Group','Total Attacks']

# %%
group_attacks
# Out:
#                                      Treeorist Group  Total Attacks
# 0                                            Taliban           7478
# 1        Islamic State of Iraq and the Levant (ISIL)           5613
# 2                                  Shining Path (SL)           4555
# 3   Farabundo Marti National Liberation Front (FMLN)           3351
# 4                                         Al-Shabaab           3288
# 5                            New People's Army (NPA)           2772
# 6                        Irish Republican Army (IRA)           2671
# 7      Revolutionary Armed Forces of Colombia (FARC)           2487
# 8                                         Boko Haram           2418
# 9                     Kurdistan Workers' Party (PKK)           2310
# 10               Basque Fatherland and Freedom (ETA)           2024
# 11    Communist Party of India - Maoist (CPI-Maoist)           1878
# 12                                           Maoists           1630
# ...

# %%
group_attacks = data.Group.value_counts().to_frame().drop('Unknown').reset_index()[:16]
group_attacks.columns =['Treeorist Group','Total Attacks']
plt.subplots(figsize=(10,8))
sns.barplot(y=group_attacks['Treeorist Group'],x = group_attacks['Total Attacks'],palette='Spectral',edgecolor=sns.color_palette('dark',10))
#plt.xticks()
plt.title('Number of total Attacks by Terrorist Group')
plt.show()

# %%
groups_10 = data[data.Group.isin(data.Group.value_counts()[1:11].index)]

# %%
pd.crosstab(groups_10.Year,groups_10.Group).plot(color=sns.color_palette('Paired',10))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.xticks(range(1970,2017,5))
plt.ylabel('Total Attacks')
plt.title('TOP Terrorist Group Activities from 1970 to 2017')
plt.legend(labels=['A1 = shabaab','Boko Haraam','FMLN','IRA','ISIL','PKK','NPA','FARC','SL','Taliban'],loc='upper left')
plt.show()

# %% [markdown]
# ##### In these line graph you can see the top terrorist group activities are increase from 1980 then it has increase,decrease gradually,suddenly it has increse in 2015 and then it also has decrease.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### 1) The hot zone countries of terrorism are iraq,afganistan,pakistan and india.

# %% [markdown]
# ####  2) The hot zone Regions are middle east,south afric,north america

# %% [markdown]
# ####  3) The most commonly used weapons are explosion and firearms.

# %% [markdown]
# #### 4)  By improving our defence on explosive and firearms will help us to reduce terrorism.

# %% [markdown]
# ## Reference

# %% [markdown]
# 1) Dataset: https://bit.ly/3F8CV9A

# %% [markdown]
# 2) www.google.com

# %% [markdown]
# 3) https://www.kaggle.com/
